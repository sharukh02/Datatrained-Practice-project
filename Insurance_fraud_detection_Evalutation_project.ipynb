# %%
# Importing Basic Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:\\Users\\ASUS\\Desktop\\datasets\\Automobile_insurance_fraud.csv")

# %% [markdown]
# ### EDA

# %%
df.head(7)
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
# 5                 256   39         104594       12-10-2006           OH
# 6                 137   34         413978       04-06-2000           IN
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# ...

# %%
pd.set_option("display.max_columns",None)
df.head(7)
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
# 5                 256   39         104594       12-10-2006           OH
# 6                 137   34         413978       04-06-2000           IN
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# ...

# %% [markdown]
# Policy_number : - Unique id provide to each Insured person'
#
# Policy_bind_date :- Date from insurance is effective
#
# Policy_deductable :- Deductable limit means if the cost of repair is above this the insurance company will pay for the damage if it is less than deductable then insurance company is not liable to pay.
#
# Umbrella_limit :- Extra layer which provide extra security to the person
#
# This dataset has ? in few columns need to check

# %%
df.shape
# Out:
# (1000, 40)

# %%
df.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.isna(),cmap='coolwarm')
plt.show()

# %% [markdown]
# The _c39 is having full nan's

# %%
df.isin(["?"]).sum()
# Out:
# months_as_customer               0
# age                              0
# policy_number                    0
# policy_bind_date                 0
# policy_state                     0
# policy_csl                       0
# policy_deductable                0
# policy_annual_premium            0
# umbrella_limit                   0
# insured_zip                      0
# insured_sex                      0
# insured_education_level          0
# insured_occupation               0
# insured_hobbies                  0
# insured_relationship             0
# capital-gains                    0
# capital-loss                     0
# incident_date                    0
# incident_type                    0
# collision_type                 178
# incident_severity                0
# authorities_contacted            0
# incident_state                   0
# incident_city                    0
# incident_location                0
# incident_hour_of_the_day         0
# number_of_vehicles_involved      0
# ...

# %%
df.nunique().sort_values(ascending=True)
# Out:
# _c39                              0
# insured_sex                       2
# fraud_reported                    2
# police_report_available           3
# bodily_injuries                   3
# policy_state                      3
# policy_csl                        3
# policy_deductable                 3
# property_damage                   3
# witnesses                         4
# number_of_vehicles_involved       4
# incident_severity                 4
# incident_type                     4
# collision_type                    4
# authorities_contacted             5
# insured_relationship              6
# incident_city                     7
# incident_state                    7
# insured_education_level           7
# umbrella_limit                   11
# auto_make                        14
# insured_occupation               14
# insured_hobbies                  20
# auto_year                        21
# incident_hour_of_the_day         24
# auto_model                       39
# ...

# %%
df["incident_date"].unique()
# Out:
# array(['25-01-2015', '21-01-2015', '22-02-2015', '10-01-2015',
#        '17-02-2015', '02-01-2015', '13-01-2015', '27-02-2015',
#        '30-01-2015', '05-01-2015', '06-01-2015', '15-02-2015',
#        '22-01-2015', '08-01-2015', '15-01-2015', '29-01-2015',
#        '19-01-2015', '01-01-2015', '10-02-2015', '11-01-2015',
#        '24-02-2015', '09-01-2015', '28-01-2015', '07-01-2015',
#        '18-01-2015', '28-02-2015', '12-02-2015', '24-01-2015',
#        '03-01-2015', '16-01-2015', '14-02-2015', '21-02-2015',
#        '18-02-2015', '26-02-2015', '17-01-2015', '27-01-2015',
#        '11-02-2015', '12-01-2015', '06-02-2015', '20-01-2015',
#        '02-02-2015', '20-02-2015', '08-02-2015', '23-02-2015',
#        '01-03-2015', '14-01-2015', '19-02-2015', '09-02-2015',
#        '26-01-2015', '23-01-2015', '31-01-2015', '03-02-2015',
#        '01-02-2015', '05-02-2015', '25-02-2015', '16-02-2015',
#        '13-02-2015', '04-02-2015', '07-02-2015', '04-01-2015'],
#       dtype=object)

# %% [markdown]
# This data is of same year of incident

# %%
df.skew()
# Out:
# months_as_customer             0.362177
# age                            0.478988
# policy_number                  0.038991
# policy_deductable              0.477887
# policy_annual_premium          0.004402
# umbrella_limit                 1.806712
# insured_zip                    0.816554
# capital-gains                  0.478850
# capital-loss                  -0.391472
# incident_hour_of_the_day      -0.035584
# number_of_vehicles_involved    0.502664
# bodily_injuries                0.014777
# witnesses                      0.019636
# total_claim_amount            -0.594582
# injury_claim                   0.264811
# property_claim                 0.378169
# vehicle_claim                 -0.621098
# auto_year                     -0.048289
# _c39                                NaN
# dtype: float64

# %% [markdown]
# ## Univariate Analysis

# %%
plt.figure(figsize=(15,6))
sns.countplot(df["age"],data=df)
plt.show()

# %% [markdown]
# Maximum people who is having insurance is lies between 26 to 48 or we can this age of people own a car

# %%
sns.distplot(df["policy_number"],color='r')
plt.show()

# %% [markdown]
# Policy_number is a unique id provide to every customer

# %%
sns.countplot(df["policy_state"],data=df)
# Out:
# <AxesSubplot:xlabel='policy_state', ylabel='count'>

# %% [markdown]
# This is data of three state i.e OH, IN and IL

# %%
sns.countplot(df["policy_csl"],data=df)
# Out:
# <AxesSubplot:xlabel='policy_csl', ylabel='count'>

# %%
sns.distplot(df["policy_deductable"],bins=30)
# Out:
# <AxesSubplot:xlabel='policy_deductable', ylabel='Density'>

# %% [markdown]
# Every policy has it's own deductable

# %%
sns.histplot(df["policy_annual_premium"],bins=30)
# Out:
# <AxesSubplot:xlabel='policy_annual_premium', ylabel='Count'>

# %% [markdown]
# The minimum policy_annual_premium is 400 and max people is purchasing inusrance having Annual_premium between 1000 to 1600 and the data also seems to be normally distributed

# %%
sns.histplot(df["umbrella_limit"],bins=30)
plt.show()

# %% [markdown]
# We have maximum zero is that columns and data is seems to skewed too much

# %%
plt.figure(figsize=(8,6))
sns.histplot(df["insured_zip"],bins=30)
plt.show()

# %% [markdown]
# insured_zip is a pincode/zipcode of the insured person

# %%
sns.countplot(df["insured_sex"],data=df)
# Out:
# <AxesSubplot:xlabel='insured_sex', ylabel='count'>

# %% [markdown]
# Female mostly take  Insurance.

# %%
plt.figure(figsize=(10,6))
sns.countplot(df["insured_education_level"],data=df)
# Out:
# <AxesSubplot:xlabel='insured_education_level', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["insured_occupation"],data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# It's is a Insured_person's occupation it also indicate that how much a person can afford or spend on insurance.

# %%
plt.figure(figsize=(8,5))
sns.countplot(df["insured_hobbies"],data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(df["insured_relationship"],data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# It's indicate that whether he is married or having a family or not

# %%
sns.histplot(df["capital-gains"],kde=True,bins=15)
# Out:
# <AxesSubplot:xlabel='capital-gains', ylabel='Count'>

# %% [markdown]
# capital_gain is maximum zero in there is few outliers due to which it shows skewness.
#
# A transfer of a part of the capital asset. That being the position, the income arising on receipt of amounts under a life insurance policy would be computed as capital gains

# %%
sns.histplot(df["capital-loss"],kde=True,bins=15)
# Out:
# <AxesSubplot:xlabel='capital-loss', ylabel='Count'>

# %% [markdown]
# A capital loss is the loss incurred when the value decreases for a capital asset.
#
# Capital_loss is left skewed and having negative value.

# %%
plt.figure(figsize=(15,6))
sns.countplot(df["incident_date"],data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# A particular date is nothing to do with the incident. The date shows the incident reported from this the insurance company get to know whether someaccident reported to the concern authority or not if it is total_loss of major accident and get the complete info about the incident from the concern authority to process the claim

# %%
plt.figure(figsize=(8,5))
sns.countplot(df["incident_type"],data=df)
# Out:
# <AxesSubplot:xlabel='incident_type', ylabel='count'>

# %% [markdown]
# The type of incident reported during claim. There is large no. of collision cases

# %%
sns.countplot(df["collision_type"])
# Out:
# <AxesSubplot:xlabel='collision_type', ylabel='count'>

# %% [markdown]
# If See there are so many cases in which collision_type is not mention.

# %%
plt.figure(figsize=(8,5))
sns.countplot(df["incident_severity"],data=df,hue="authorities_contacted")
plt.show()

# %% [markdown]
# There is some Trivial Damage cases as well which may be not compensated if it is in policy_deductable limit

# %%
plt.figure(figsize=(10,8))
sns.countplot(df["authorities_contacted"],data=df,hue="incident_type")
plt.show()

# %% [markdown]
# There are cases in which no one contacted any authority or file any fir as we can see in above graph

# %%
sns.countplot(df["incident_state"],data=df)
# Out:
# <AxesSubplot:xlabel='incident_state', ylabel='count'>

# %% [markdown]
# Most of the cases is from NY and SC

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["number_of_vehicles_involved"],data=df,hue="authorities_contacted")
plt.xticks(rotation=90)
plt.tight_layout()

# %% [markdown]
# In a single vehicle collision there are cases in which no authorities were contacted

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["property_damage"],data=df,hue="authorities_contacted")
plt.xticks(rotation=90)
plt.tight_layout()

# %% [markdown]
# There are many cases in which even after property damage None authorities were contacted

# %%
sns.countplot(df["bodily_injuries"],data=df)
# Out:
# <AxesSubplot:xlabel='bodily_injuries', ylabel='count'>

# %%
sns.histplot(df["witnesses"])
# Out:
# <AxesSubplot:xlabel='witnesses', ylabel='Count'>

# %%
sns.countplot(df["police_report_available"],hue="fraud_reported",data=df)
# Out:
# <AxesSubplot:xlabel='police_report_available', ylabel='count'>

# %% [markdown]
# we can't say with surity that having the police report means that person is making a genuine claim.

# %%
df["total_claim_amount"].plot.hist(bins=40)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# The claim amount has few outliers

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(df["injury_claim"],data=df,fill=True)
plt.show()

# %% [markdown]
# Injury amount also having Outliers and right skewed

# %%
sns.distplot(df["property_claim"])
# Out:
# <AxesSubplot:xlabel='property_claim', ylabel='Density'>

# %%
sns.distplot(df["vehicle_claim"])
# Out:
# <AxesSubplot:xlabel='vehicle_claim', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.countplot(df["auto_make"],data=df)
plt.xticks(rotation=90)
plt.tight_layout()

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["auto_model"])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["auto_year"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Insurance premium and cost of car is depreciated with the time

# %%
sns.countplot(df["fraud_reported"],data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %% [markdown]
# There is class imbalancement in this dataset

# %% [markdown]
# ### Bivariate Analysis

# %%
cont = df.select_dtypes(exclude="object").columns

# %%
plt.figure(figsize=(10,5))
sns.swarmplot(df["auto_make"],df["total_claim_amount"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Total_claim amount is higher in Audi

# %%
plotnumber =1
plt.figure(figsize=(30,50))
for i in df.drop(["policy_bind_date","incident_date","incident_location"],axis=1):
    if plotnumber < 41:
        ax = plt.subplot(10,4,plotnumber)
        sns.stripplot(df["fraud_reported"],df[i])
        plt.yticks(rotation=0)
        plotnumber+=1
plt.show()

# %% [markdown]
# policy_bind_date","incident_date","incident_location

# %%
plotnumber =1
plt.figure(figsize=(30,50))
for i in df[cont]:
    if plotnumber < 41:
        ax = plt.subplot(10,4,plotnumber)
        sns.violinplot(df["fraud_reported"],df[i])
        plt.yticks(rotation=0)
        plotnumber+=1
plt.show()

# %% [markdown]
# As the claim amount increases the chances of Fraud also increases

# %% [markdown]
# #### Before further Analysis need to take care of things

# %%
df["policy_bind_date"] = pd.to_datetime(df["policy_bind_date"])
df["policy_bind_day"] =  df["policy_bind_date"].dt.day

# %%
df["policy_bind_month"] =  df["policy_bind_date"].dt.month

# %%
df["policy_bind_year"] =  df["policy_bind_date"].dt.year

# %%
df["incident_date"] = pd.to_datetime(df["incident_date"])
df["incident_day"] = df["incident_date"].dt.day
df["incident_month"] = df["incident_date"].dt.month
df["incident_year"] = df["incident_date"].dt.year

# %%
policy_csl = list(df["policy_csl"])

policy_csl1 = []
policy_csl2 = []
for i in range(len(policy_csl)):
    policy_csl1.append(policy_csl[i].split(sep='/')[0])
    policy_csl2.append(policy_csl[i].split(sep='/')[-1])

# %%
df["policy_csl1"] = policy_csl1
df["policy_csl2"] = policy_csl2

# %%
# converting that column into int
df["policy_csl1"] = df["policy_csl1"].astype("int32")
df["policy_csl2"] = df["policy_csl2"].astype("int32")

# %%
df.drop(["policy_csl","incident_date","policy_bind_date"],axis=1,inplace=True)

# %%
# can't fill that data with mode so filling with a new value
df["police_report_available"] = df["police_report_available"].replace("?","No info Available")

# %%
# can't fill that data with mode so filling with a new value
df["property_damage"] = df["property_damage"].replace("?","No info Available")
df["collision_type"] = df["collision_type"].replace("?",df["collision_type"].mode()[0])

# %%
cat = df.select_dtypes(exclude=np.number).columns

# %%
from sklearn.preprocessing import OrdinalEncoder
ord_enc = OrdinalEncoder()
for i in cat:
    df[[i]] = ord_enc.fit_transform(df[[i]])

# %% [markdown]
# ### Multivariate Analysis

# %%
df_corr = df.corr().abs()
plt.figure(figsize=(50,50))
sns.heatmap(df_corr,annot=True,square=True,center=0,fmt='0.2g',vmin=-1,vmax=1)
plt.show()

# %% [markdown]
# There is two columns i.e _c39 and incident_year both of them has no relation with the **Target Columns.**
#
# age and months_as_customer show a high colinearity need to confirm it.
#
# total claim, property_claim and vehicle claim also showing multicollinearity issues, total_claim and vehicle claim has more than 90 percent collinearity.

# %%
sns.violinplot(df["fraud_reported"],df["total_claim_amount"])
plt.show()

# %%
sns.violinplot(df["fraud_reported"],df["vehicle_claim"])
plt.show()

# %% [markdown]
# Vehicle claim and total_claim has the same relation with target variables and it is confirmed with above two plots.

# %%
sns.violinplot(df["fraud_reported"],df["property_claim"])
plt.show()

# %%
df.corr()["fraud_reported"].abs()
# Out:
# months_as_customer             0.020544
# age                            0.012143
# policy_number                  0.029443
# policy_state                   0.029432
# policy_deductable              0.014817
# policy_annual_premium          0.014480
# umbrella_limit                 0.058622
# insured_zip                    0.019368
# insured_sex                    0.030873
# insured_education_level        0.008808
# insured_occupation             0.001564
# insured_hobbies                0.046838
# insured_relationship           0.021043
# capital-gains                  0.019173
# capital-loss                   0.014863
# incident_type                  0.050376
# collision_type                 0.017315
# incident_severity              0.405988
# authorities_contacted          0.045802
# incident_state                 0.051407
# incident_city                  0.040403
# incident_location              0.008832
# incident_hour_of_the_day       0.004316
# ...

# %% [markdown]
# Confirmed that incident_year and _c39 has no relation with the target variable

# %% [markdown]
# ## DataCleaning

# %%
df.drop(["_c39","incident_year"],axis=1,inplace=True)

# %%
plotnumber =1
plt.figure(figsize=(30,50))
for i in df:
    if plotnumber < 44:
        ax = plt.subplot(11,4,plotnumber)
        sns.boxplot(df[i])
        plt.yticks(rotation=0)
        plotnumber+=1
plt.show()

# %% [markdown]
# age, policy_annual_premium, umbrella_limit, property_claim, total_claim_amount and incident_month has outliers. Except incident_month remainings are contineous columns

# %%
### Applying z score
from scipy.stats import zscore
zscr = zscore(df[["age","policy_annual_premium","umbrella_limit","property_claim","total_claim_amount"]])

# %%
abs_zscr = np.abs(zscr)
filter = ((abs_zscr < 3) & (abs_zscr > -3)).all(axis=1)

# %%
new_df = df[filter]

# %%
new_df.shape
# Out:
# (981, 43)

# %%
# Removing Outliers from some columns
q3 = new_df.quantile(0.75)
q1 = new_df.quantile(0.25)
iqr = q3-q1
max = q3["age"] + (1.5*iqr["age"])
index = np.where(new_df["age"] > max)
new_df.drop(new_df.index[index],inplace=True)

# %%
# Removing Outliers from policy annual premium
max = q3["policy_annual_premium"] + (1.5*iqr["policy_annual_premium"])
index = np.where(new_df["policy_annual_premium"] > max)
new_df.drop(new_df.index[index],inplace=True)

min = q1["policy_annual_premium"] - (1.5*iqr["policy_annual_premium"])
index = np.where(new_df["policy_annual_premium"] < min)
new_df.drop(new_df.index[index],inplace=True)

# %%
# Removing Outliers from policy annual premium
max = q3["property_claim"] + (1.5*iqr["property_claim"])
index = np.where(new_df["property_claim"] > max)
new_df.drop(new_df.index[index],inplace=True)

# %%
# Removing Outliers from total_claim_amount
max = q3["total_claim_amount"] + (1.5*iqr["total_claim_amount"])
index = np.where(new_df["total_claim_amount"] > max)
new_df.drop(new_df.index[index],inplace=True)

# %%
min = q1["umbrella_limit"] - (1.5*iqr["umbrella_limit"])
index = np.where(new_df["umbrella_limit"] < min)
new_df.drop(new_df.index[index],inplace=True)

# %% [markdown]
# ### If i remove the Outliers of Umbrella the loss will be greater than 10% and moreover we need Umbrella Outliers to understand that column data

# %%
# # Removing Outliers from policy annual premium
# max = q3["umbrella_limit"] + (1.5*iqr["umbrella_limit"])
# index = np.where(new_df["umbrella_limit"] > max)
# new_df.drop(new_df.index[index],inplace=True)

# %%
new_df.shape
# Out:
# (964, 43)

# %%
print("Data Loss percent is :",((1000-964)/1000)*100)
# Out:
# Data Loss percent is : 3.5999999999999996

# %%
plotnumber =1
plt.figure(figsize=(30,50))
for i in new_df:
    if plotnumber < 44:
        ax = plt.subplot(11,4,plotnumber)
        sns.boxplot(new_df[i])
        plt.yticks(rotation=0)
        plotnumber+=1
plt.show()

# %%
plotnumber =1
plt.figure(figsize=(30,50))
for i in new_df:
    if plotnumber < 44:
        ax = plt.subplot(11,4,plotnumber)
        sns.distplot(new_df[i])
        plotnumber+=1
plt.show()

# %% [markdown]
# There are few columns which still has skewness

# %%
new_df.skew().to_frame(name="skewness")
# Out:
#                              skewness
# months_as_customer           0.344754
# age                          0.438999
# policy_number                0.038200
# policy_state                -0.044555
# policy_deductable            0.466439
# policy_annual_premium        0.001882
# umbrella_limit               1.813028
# insured_zip                  0.855307
# insured_sex                  0.145840
# insured_education_level      0.007519
# insured_occupation          -0.057233
# insured_hobbies             -0.038825
# insured_relationship         0.078491
# capital-gains                0.464146
# capital-loss                -0.385615
# incident_type                0.097319
# collision_type              -0.030042
# incident_severity            0.274517
# authorities_contacted       -0.117965
# incident_state              -0.143777
# incident_city                0.039485
# incident_location            0.002619
# incident_hour_of_the_day    -0.032221
# number_of_vehicles_involved  0.502285
# ...

# %%
features = ["umbrella_limit","total_claim_amount","vehicle_claim"]

# %%
new_df["umbrella_limit"] = np.power(new_df["umbrella_limit"],(1/3))

# %%
from sklearn.preprocessing import QuantileTransformer
qt = QuantileTransformer()

# %%
new_df[features] = qt.fit_transform(new_df[features])

# %%
new_df.skew()
# Out:
# months_as_customer             0.344754
# age                            0.438999
# policy_number                  0.038200
# policy_state                  -0.044555
# policy_deductable              0.466439
# policy_annual_premium          0.001882
# umbrella_limit                 1.611203
# insured_zip                    0.855307
# insured_sex                    0.145840
# insured_education_level        0.007519
# insured_occupation            -0.057233
# insured_hobbies               -0.038825
# insured_relationship           0.078491
# capital-gains                  0.464146
# capital-loss                  -0.385615
# incident_type                  0.097319
# collision_type                -0.030042
# incident_severity              0.274517
# authorities_contacted         -0.117965
# incident_state                -0.143777
# incident_city                  0.039485
# incident_location              0.002619
# incident_hour_of_the_day      -0.032221
# ...

# %%
sns.countplot(new_df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %%
# Taking care of imbalace of the Target columns
from sklearn.utils import resample
fraud = new_df[new_df["fraud_reported"]==0]
no_fraud = new_df[new_df["fraud_reported"]==1]

# %%
up_sampled = resample(no_fraud,replace=True,n_samples=len(fraud),random_state=0)

# %%
new_df=pd.concat([fraud,up_sampled])

# %%
sns.countplot(new_df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %%
x = new_df.drop("fraud_reported",axis=1)
y = new_df["fraud_reported"]

# %%
from sklearn.feature_selection import SelectKBest,SelectPercentile,f_classif,chi2

# %%
spercentile = SelectPercentile(score_func = f_classif,percentile=90)
spercentile = spercentile.fit(x,y)

# %%
cols = spercentile.get_support(indices=True)
feature = x.columns[cols]

# %%
df_score = pd.DataFrame({"feature":x.columns,"f_score":spercentile.scores_,"pvalue":spercentile.pvalues_})

# %%
df_score.sort_values(by='f_score',ascending=False)
# Out:
#                         feature     f_score        pvalue
# 17            incident_severity  436.302903  5.890895e-85
# 30               property_claim   47.445552  8.388005e-12
# 31                vehicle_claim   43.905002  4.839011e-11
# 28           total_claim_amount   37.232991  1.341326e-09
# 11              insured_hobbies   15.391876  9.143360e-05
# 19               incident_state   10.904596  9.825114e-04
# 29                 injury_claim    7.955536  4.859070e-03
# 38                 incident_day    7.612852  5.867950e-03
# 24              property_damage    7.074357  7.905294e-03
# 8                   insured_sex    6.341828  1.189881e-02
# 23  number_of_vehicles_involved    5.217955  2.249820e-02
# 2                 policy_number    4.904217  2.694556e-02
# 26                    witnesses    4.086919  4.339897e-02
# 20                incident_city    3.786041  5.187395e-02
# 41                  policy_csl2    3.133572  7.690475e-02
# ...

# %% [markdown]
# From above **pvalues we can see that only top 13 features is related to the features so i am building the model by taking only that features in to consideration**

# %%
x = new_df[["incident_severity","property_claim","vehicle_claim","total_claim_amount","insured_hobbies","incident_state",
           "injury_claim","incident_day","property_damage","insured_sex","number_of_vehicles_involved","policy_number",
           "witnesses"]]
y = new_df["fraud_reported"]

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier,RandomForestClassifier,BaggingClassifier,VotingClassifier,AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV,RandomizedSearchCV,KFold

# %%
scale = StandardScaler()
x_scaled = scale.fit_transform(x)

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.25,random_state=100)

# %%
kf = KFold(n_splits=5,random_state=100)

# %% [markdown]
# ### LogisticRegression

# %%
log_reg = LogisticRegression()
log_reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = log_reg.predict(x_test)

# %%
a= accuracy_score(y_test,y_pred)

# %%
c= cross_val_score(log_reg,x_scaled,y,cv=kf).mean()

# %%
print("Accuracy Score :",a,"\n","=-"*60,"\n Cross validation score :",c,"\n","=-"*60,"\nClassification report :\n",classification_report(y_test,y_pred),
     "\n","=-"*60,"\nConfusion_matrix :\n",confusion_matrix(y_test,y_pred))
# Out:
# Accuracy Score : 0.7863013698630137
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
#  Cross validation score : 0.6234853834204208
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Classification report :
#                precision    recall  f1-score   support
#
#          0.0       0.83      0.74      0.78       189
#          1.0       0.75      0.84      0.79       176
#
#     accuracy                           0.79       365
#    macro avg       0.79      0.79      0.79       365
# weighted avg       0.79      0.79      0.79       365
#
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Confusion_matrix :
#  [[140  49]
#  [ 29 147]]

# %%
accu = []
cross = []
diff = []
accu.append(a)
cross.append(c)
diff.append(a-c)

# %% [markdown]
# ### BaggingClassifier

# %%
bag_clf = BaggingClassifier()
bag_clf.fit(x_train,y_train)
# Out:
# BaggingClassifier()

# %%
y_pred = bag_clf.predict(x_test)

# %%
a = accuracy_score(y_test,y_pred)

# %%
c = cross_val_score(bag_clf,x_scaled,y,cv=kf).mean()

# %%
print("Accuracy Score :",a,"\n","=-"*60,"\n Cross validation score :",c,"\n","=-"*60,"\nClassification report :\n",classification_report(y_test,y_pred),
     "\n","=-"*60,"\nConfusion_matrix :\n",confusion_matrix(y_test,y_pred))
# Out:
# Accuracy Score : 0.9342465753424658
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
#  Cross validation score : 0.880014593042414
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Classification report :
#                precision    recall  f1-score   support
#
#          0.0       0.98      0.89      0.93       189
#          1.0       0.89      0.98      0.94       176
#
#     accuracy                           0.93       365
#    macro avg       0.94      0.94      0.93       365
# weighted avg       0.94      0.93      0.93       365
#
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Confusion_matrix :
#  [[168  21]
#  [  3 173]]

# %%
accu.append(a)
cross.append(c)
diff.append(a-c)

# %% [markdown]
# ### RandomForestClassifier

# %%
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(x_test)

# %%
a = accuracy_score(y_test,y_pred)

# %%
c = cross_val_score(rf,x_scaled,y,cv=kf).mean()

# %%
print("Accuracy Score :",a,"\n","=-"*60,"\n Cross validation score :",c,"\n","=-"*60,"\nClassification report :\n",classification_report(y_test,y_pred),
     "\n","=-"*60,"\nConfusion_matrix :\n",confusion_matrix(y_test,y_pred))
# Out:
# Accuracy Score : 0.9205479452054794
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
#  Cross validation score : 0.8889210563479735
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Classification report :
#                precision    recall  f1-score   support
#
#          0.0       0.97      0.88      0.92       189
#          1.0       0.88      0.97      0.92       176
#
#     accuracy                           0.92       365
#    macro avg       0.92      0.92      0.92       365
# weighted avg       0.92      0.92      0.92       365
#
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Confusion_matrix :
#  [[166  23]
#  [  6 170]]

# %%
accu.append(a)
cross.append(c)
diff.append(a-c)

# %% [markdown]
# ### XGBClassifier

# %%
xgb = XGBClassifier(verbosity=0)
xgb.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=0)

# %%
y_pred = xgb.predict(x_test)

# %%
a = accuracy_score(y_test,y_pred)

# %%
c = cross_val_score(xgb,x_scaled,y,cv=kf).mean()

# %%
print("Accuracy Score :",a,"\n","=-"*60,"\n Cross validation score :",c,"\n","=-"*60,"\nClassification report :\n",classification_report(y_test,y_pred),
     "\n","=-"*60,"\nConfusion_matrix :\n",confusion_matrix(y_test,y_pred))
# Out:
# Accuracy Score : 0.9123287671232877
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
#  Cross validation score : 0.8958033234477238
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Classification report :
#                precision    recall  f1-score   support
#
#          0.0       0.96      0.87      0.91       189
#          1.0       0.87      0.96      0.91       176
#
#     accuracy                           0.91       365
#    macro avg       0.92      0.91      0.91       365
# weighted avg       0.92      0.91      0.91       365
#
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Confusion_matrix :
#  [[164  25]
#  [  7 169]]

# %%
accu.append(a)
cross.append(c)
diff.append(a-c)

# %% [markdown]
# ### DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(x_test)

# %%
a = accuracy_score(y_test,y_pred)

# %%
c = cross_val_score(dt,x_scaled,y,cv=kf).mean()

# %%
print("Accuracy Score :",a,"\n","=-"*60,"\n Cross validation score :",c,"\n","=-"*60,"\nClassification report :\n",classification_report(y_test,y_pred),
     "\n","=-"*60,"\nConfusion_matrix :\n",confusion_matrix(y_test,y_pred))
# Out:
# Accuracy Score : 0.9068493150684932
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
#  Cross validation score : 0.8704067222143765
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Classification report :
#                precision    recall  f1-score   support
#
#          0.0       0.96      0.86      0.91       189
#          1.0       0.86      0.96      0.91       176
#
#     accuracy                           0.91       365
#    macro avg       0.91      0.91      0.91       365
# weighted avg       0.91      0.91      0.91       365
#
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Confusion_matrix :
#  [[162  27]
#  [  7 169]]

# %%
accu.append(a)
cross.append(c)
diff.append(a-c)

# %%
model = ["LogisticRegression","BaggingClassifier","RandomForestClassifier","XGBClassifier","DecisionTreeClassifier"]

# %%
classifier = pd.DataFrame({"MODEL":model,"Accuracy score":accu,"Cross_validation_Score":cross,"Difference":diff})

classifier
# Out:
#                     MODEL  Accuracy score  Cross_validation_Score  Difference
# 0      LogisticRegression        0.786301                0.623485    0.162816
# 1       BaggingClassifier        0.934247                0.880015    0.054232
# 2  RandomForestClassifier        0.920548                0.888921    0.031627
# 3           XGBClassifier        0.912329                0.895803    0.016525
# 4  DecisionTreeClassifier        0.906849                0.870407    0.036443

# %% [markdown]
# #### XGB is my Best Model

# %% [markdown]
# ### Hyperparameter Tuning

# %%
param = {"learning_rate":[0.001,0.01,0.0001,1],
         "booster":["gbtree","gblinear"],
         'max_delta_step':[0.2,3.2,3.77,2.2,5.2,7.2,9,8.56],
         "max_depth":[7,8,10,15,35,37],
         "n_estimators":[100,200,500],
         "gamma":[0.5,0.9,0.3,0.4]
         }

# %%
rand_search = RandomizedSearchCV(xgb,param_distributions=param,cv=3,n_jobs=-1)

# %%
rand_search.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=3,
#                    estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                            colsample_bylevel=1,
#                                            colsample_bynode=1,
#                                            colsample_bytree=1, gamma=0.4,
#                                            gpu_id=-1, importance_type='gain',
#                                            interaction_constraints='',
#                                            learning_rate=1, max_delta_step=3.2,
#                                            max_depth=15, min_child_weight=1,
#                                            missing=nan,
#                                            monotone_constraints='()',
#                                            n_estimators=500, n_jobs=8,
#                                            num_paralle...
#                                            reg_alpha=0, reg_lambda=1,
# ...

# %%
rand_search.best_params_
# Out:
# {'n_estimators': 100,
#  'max_depth': 8,
#  'max_delta_step': 0.2,
#  'learning_rate': 0.001,
#  'gamma': 0.5,
#  'booster': 'gbtree'}

# %%
xgb = XGBClassifier(n_estimators=100,booster='gbtree',max_depth=8,max_delta_step=0.2,learning_rate=0.001,gamma=0.5)
xgb.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0.5, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.001, max_delta_step=0.2, max_depth=8,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred = rf.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9205479452054794

# %%
cross_val_score(xgb,x_scaled,y,cv=5).mean()
# Out:
# 0.9197665113213764

# %%
from sklearn.metrics import roc_curve,roc_auc_score,plot_roc_curve

# %%
#LogisticRegression
print("log_reg roc_auc_score",roc_auc_score(y_test,log_reg.predict(x_test)))

#Knn
print("RandomForestClassifier roc_auc_score",roc_auc_score(y_test,rf.predict(x_test)))

#BaggingClassifier
print("Bag_clf roc_auc_score",roc_auc_score(y_test,bag_clf.predict(x_test)))

#GradientBossting
print("XGBClassifier roc_auc_score",roc_auc_score(y_test,xgb.predict(x_test)))

#DecisionTree
print("DecisionTreeClassifier roc_auc_score",roc_auc_score(y_test,dt.predict(x_test)))
# Out:
# log_reg roc_auc_score 0.7879840067340067
# RandomForestClassifier roc_auc_score 0.9221079846079847
# Bag_clf roc_auc_score 0.9359217171717171
# XGBClassifier roc_auc_score 0.9253397065897065
# DecisionTreeClassifier roc_auc_score 0.908685064935065

# %%
plt.style.use('seaborn')

disp = plot_roc_curve(log_reg,x_test,y_test,color='orange')
plot_roc_curve(rf,x_test,y_test,color='b',ax=disp.ax_)
plot_roc_curve(bag_clf,x_test,y_test,color='green',ax=disp.ax_)
plot_roc_curve(xgb,x_test,y_test,color='red',ax=disp.ax_)
plot_roc_curve(dt,x_test,y_test,color='c',ax=disp.ax_)


plt.title('ROC curve')

plt.xlabel('False Positive Rate')

plt.ylabel('True Positive rate')

plt.legend(loc='best')
plt.savefig('ROC',dpi=300)
plt.show();

# %% [markdown]
# ### Saving model

# %%
import pickle
pickle.dump(xgb,open("Insurance.pk1","wb"))

# %%
load_model = pickle.load(open("Insurance.pk1","rb"))
