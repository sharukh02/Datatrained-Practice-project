# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:\\Users\\ASUS\\Desktop\\datasets\\census_income.csv")

# %% [markdown]
# ## EDA

# %%
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %% [markdown]
# df.shape

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.isna().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# __There is no missing values in this dataset__

# %%
df.nunique().sort_values()
# Out:
# Sex                   2
# Income                2
# Race                  5
# Relationship          6
# Marital_status        7
# Workclass             9
# Occupation           15
# Education            16
# Education_num        16
# Native_country       42
# Age                  73
# Capital_loss         92
# Hours_per_week       94
# Capital_gain        119
# Fnlwgt            21647
# dtype: int64

# %%
df["Race"].unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
df["Relationship"].unique()
# Out:
# array([' Husband', ' Not-in-family', ' Wife', ' Own-child', ' Unmarried',
#        ' Other-relative'], dtype=object)

# %%
df["Marital_status"].unique()
# Out:
# array([' Married-civ-spouse', ' Divorced', ' Married-spouse-absent',
#        ' Never-married', ' Separated', ' Married-AF-spouse', ' Widowed'],
#       dtype=object)

# %%
df["Workclass"].unique()
# Out:
# array([' Self-emp-not-inc', ' Private', ' State-gov', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %% [markdown]
# This column has **"?"**. Means missing data about that particular person or we can say that Workclass is unknown. We need to take care of that.

# %%
df["Education"].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
df["Education"] = df["Education"].replace([" 11th"," 9th"," 7th-8th"," 5th-6th"," 10th"," 1st-4th"," 12th"],"school")

# %%
# cheking for " ?" in dataframe
df.isin([" ?"]).sum()
# Out:
# Age                  0
# Workclass         1836
# Fnlwgt               0
# Education            0
# Education_num        0
# Marital_status       0
# Occupation        1843
# Relationship         0
# Race                 0
# Sex                  0
# Capital_gain         0
# Capital_loss         0
# Hours_per_week       0
# Native_country     583
# Income               0
# dtype: int64

# %% [markdown]
# We have ? in place of Nan's in object dtypes columns and need to take care unwanted spaces given before anyword

# %%
# checking for the blank spaces in the dataframe
df.isin([" "]).sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# There is no blank spaces in the dataframe

# %%
# checking for the zero
df.isin([0]).sum()
# Out:
# Age                   0
# Workclass             0
# Fnlwgt                0
# Education             0
# Education_num         0
# Marital_status        0
# Occupation            0
# Relationship          0
# Race                  0
# Sex                   0
# Capital_gain      29849
# Capital_loss      31041
# Hours_per_week        0
# Native_country        0
# Income                0
# dtype: int64

# %%
df.isin([0]).sum().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# As we can see there are two columns which contain zero init . Capital_loss and Capital_gain column contain almost 90% zero.

# %% [markdown]
# ### Univariate Analysis

# %%
sns.countplot(df["Income"],data=df)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %% [markdown]
# <=50k is the majority class and other is minority class. There is Class imbalanced i need to take care of that.

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["Workclass"],data=df)
# Out:
# <AxesSubplot:xlabel='Workclass', ylabel='count'>

# %% [markdown]
# We have large no. of Private Employee data in this dataset or we can say that most of the people working in Private sector as compare to other and the least no of employee in Federal goverment

# %%
plt.figure(figsize=(10,7))
sns.countplot(df["Education"],data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Most of the people just complete High school Graduation.

# %%
plt.figure(figsize=(10,7))
sns.countplot(df["Education_num"],data=df)
# Out:
# <AxesSubplot:xlabel='Education_num', ylabel='count'>

# %% [markdown]
# The most frequent Education_num is 9 then 10

# %%
plt.figure(figsize=(12,7))
sns.countplot(df["Marital_status"],data=df)
# Out:
# <AxesSubplot:xlabel='Marital_status', ylabel='count'>

# %% [markdown]
# Marital status of that particular person whose data is recorded. In this dataset we have large no. of data of Married-civ-spouse and the person who Never-Married

# %%
plt.figure(figsize=(8,5))
sns.countplot(df["Occupation"],data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# It shows the job_occupation count of this dataset. As we can say that most of the people either work at Managerical, prof-speciality or at craft_repair work. __We also have the missing value in this dataset in form of " ?"__

# %%
plt.figure(figsize=(8,5))
sns.countplot(df["Relationship"],data=df)
# Out:
# <AxesSubplot:xlabel='Relationship', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["Race"],data=df)
# Out:
# <AxesSubplot:xlabel='Race', ylabel='count'>

# %% [markdown]
# Most of the data is belong to American white race.

# %%
plt.figure(figsize=(5,5))
sns.countplot(df["Sex"],data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# Ordinal Data

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["Native_country"],data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Most of the data is belong to American

# %%
num = df.select_dtypes(exclude="object").columns

# %%
plt.figure(figsize=(20,15))
plotnumber = 1
for i in df[num]:
    if plotnumber < 16:
        ax= plt.subplot(5,3,plotnumber)
        sns.kdeplot(df[i],data=df,fill=True,color='r')
        plt.xlabel(i,fontsize=10)
        plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Fniwgt column data is seemed to be left skewed
#
# Age is also seems to be left skewed
#
# Education_num data seems to right skewed
#
# capital_gain and capital_loss both are skewed too much.
#
#
# Hours_per_week is skewed both side.

# %%
df.skew().to_frame("Skewness")
# Out:
#                  Skewness
# Age              0.558738
# Fnlwgt           1.446972
# Education_num   -0.311630
# Capital_gain    11.953690
# Capital_loss     4.594549
# Hours_per_week   0.227636

# %% [markdown]
# ## Bivariate Analysis

# %%
plt.figure(figsize=(15,35))
plotnumber=1
for i in df:
    if plotnumber < 16:
        ax= plt.subplot(8,2,plotnumber)
        sns.stripplot(df["Income"],df[i])
        plt.ylabel(i,fontsize=10)
        plotnumber+=1
plt.show()

# %% [markdown]
# * Age is seem to be have same realtion with less than or greater than 50k
# *  Fnlwgt has some Outliers in less than 50k
# * There is an Exception cases in Education where we can see few dots in 1st-4th and 5th-6th which means there are very few people who get more than 50k remaining is same in both the classes

# %%
df.shape
# Out:
# (32560, 15)

# %%
#Filling the " ? values" because loosing that data means we have loose some crucial information
df["Workclass"] = df["Workclass"].replace(" ?",df["Workclass"].mode()[0])
df["Occupation"] = df["Occupation"].replace(" ?",df["Occupation"].mode()[0])
df["Native_country"] = df["Native_country"].replace(" ?",df["Native_country"].mode()[0])

# %%
df["Marital_status"].unique()
# Out:
# array([' Married-civ-spouse', ' Divorced', ' Married-spouse-absent',
#        ' Never-married', ' Separated', ' Married-AF-spouse', ' Widowed'],
#       dtype=object)

# %%
# As we can above there are two categories which are married but written as Married-civ-spouse and Married-AF-spouse making it one column
df["Marital_status"] = df["Marital_status"].replace([" Married-civ-spouse"," Married-AF-spouse"],"Married")

# %%
# Making Separated and Divorced one category by replacing them with divorced
df["Marital_status"] = df["Marital_status"].replace([" Divorced"," Separated"],"Divorced")

df["Marital_status"] = df["Marital_status"].replace([" Married-spouse-absent"," Never-married"," Widowed"],"other")

# %%
sns.countplot(df["Marital_status"],data=df,hue='Income')
# Out:
# <AxesSubplot:xlabel='Marital_status', ylabel='count'>

# %% [markdown]
# from above graph we can see that there are people who are married has the higher probability of having income greater than 50k

# %%
plt.figure(figsize=(10,8))
sns.countplot(df["Workclass"],data=df,hue="Income")
plt.show()

# %% [markdown]
# The people working in private sector has the Income more than 50k but the people working in private sector is higher as compared to other sector in our dataset so we can't say this with surity

# %%
plt.figure(figsize=(10,8))
sns.countplot(df["Occupation"],data=df,hue="Income")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The person is at managerial position has both the categories almost equal less and greater than 50k

# %%
plt.figure(figsize=(10,8))
sns.countplot(df["Native_country"],data=df,hue="Income")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The people whom US is the Native_country has the higher probablity as compare to other country of having salary greater than 50k

# %%
obj =['Workclass', 'Education', 'Marital_status', 'Occupation','Relationship', 'Race', 'Sex', 'Native_country', 'Income']

# %%
from sklearn.preprocessing import OrdinalEncoder
ord_enc = OrdinalEncoder()

# %%
for i in df[obj]:
    df[[i]] = ord_enc.fit_transform(df[[i]])

# %%
df_corr = df.corr().abs()
plt.figure(figsize=(20,20))
sns.heatmap(df_corr,square=True,annot=True,fmt='.2g',vmin=-1,vmax=1)
plt.show()

# %% [markdown]
# - Education_num is showing the highest correlation with Target variable
# - Fnlwgt has showing least correlation with the target column
# - Sex and Relationship is showing 58% correlation with each other we need to check which feature we can keep and remove during final model Building

# %%
# Just confirming the correlation with target Variable
df.corr()['Income'].abs()
# Out:
# Age               0.234039
# Workclass         0.002739
# Fnlwgt            0.009481
# Education         0.160736
# Education_num     0.335182
# Marital_status    0.154153
# Occupation        0.034599
# Relationship      0.250924
# Race              0.071853
# Sex               0.215995
# Capital_gain      0.223333
# Capital_loss      0.150523
# Hours_per_week    0.229690
# Native_country    0.023063
# Income            1.000000
# Name: Income, dtype: float64

# %% [markdown]
# ## Datacleaning

# %%
plotnumber = 1
plt.figure(figsize=(15,30))
for i in df:
    if plotnumber < 16:
        ax = plt.subplot(8,2,plotnumber)
        sns.boxplot(df[i])
        plt.xlabel(i,fontsize=10)
        plotnumber+=1
plt.show()

# %% [markdown]
# We have Five contineous data columns i.e Fnlwgt, Capital_gain, capital_loss, Age and Hours_per_week. All of them have Outliers in it.
#
# But it is possible to have Outliers in Age. May be somepeople are still working or earning by business so i am not going to take care of the Outliers in Age columns.
#
#
# Similar with Hours_per_week may be some people working extra hours to earn extra income

# %%
plotnumber = 1
plt.figure(figsize=(15,30))
for i in df:
    if plotnumber < 16:
        ax = plt.subplot(8,2,plotnumber)
        sns.distplot(df[i])
        plt.xlabel(i,fontsize=10)
        plotnumber+=1
plt.show()

# %% [markdown]
# By looking above both the graphs i can say that there is only three columns which have Outliers and Skewness as well i.e Capital_loss, Capital_gain and Fnlwgt. Need to take care of it.

# %%
features = ["Capital_loss","Capital_gain","Fnlwgt"]

# %%
# Creating a copy of dataframe
new_df = pd.DataFrame(df)

# %%
q1 = new_df.quantile(0.25)
q3 = new_df.quantile(0.75)
iqr = q3 - q1

# %%
max = q3["Capital_loss"]+(1.5+iqr["Capital_loss"])
index = np.where(new_df["Capital_loss"] > max)
new_df.drop(new_df.index[index],inplace=True)

# %%
max = q3["Capital_gain"]+(1.5+iqr["Capital_gain"])
index = np.where(new_df["Capital_gain"] > max)
new_df.drop(new_df.index[index],inplace=True)

# %%
new_df.skew()
# Out:
# Age               0.596681
# Workclass         0.108723
# Fnlwgt            1.465137
# Education         0.049678
# Education_num    -0.335779
# Marital_status   -0.357672
# Occupation        0.001951
# Relationship      0.703193
# Race             -2.379913
# Sex              -0.651314
# Capital_gain      0.000000
# Capital_loss      0.000000
# Hours_per_week    0.227554
# Native_country   -4.186524
# Income            1.578079
# dtype: float64

# %% [markdown]
# Capital_loss and gain skewness has been taken care only Fnlwgt has Outliers and Skewness now

# %%
plotnumber = 1
plt.figure(figsize=(15,30))
for i in new_df:
    if plotnumber < 16:
        ax = plt.subplot(8,2,plotnumber)
        sns.boxplot(new_df[i])
        plt.xlabel(i,fontsize=10)
        plotnumber+=1
plt.show()

# %%
plotnumber = 1
plt.figure(figsize=(15,30))
for i in new_df:
    if plotnumber < 16:
        ax = plt.subplot(8,2,plotnumber)
        sns.distplot(new_df[i],kde=True,color='r')
        plt.xlabel(i,fontsize=10)
        plotnumber+=1
plt.show()

# %% [markdown]
# Data loss is Maximum but still data has outliers and skewness in Fnlwgt

# %%
# Taking Care of Skewness
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer()

# %%
new_df[["Fnlwgt"]] = pt.fit_transform(new_df[["Fnlwgt"]])

# %%
new_df.skew().to_frame(name="Skewness_score")
# Out:
#                 Skewness_score
# Age                   0.596681
# Workclass             0.108723
# Fnlwgt                0.016465
# Education             0.049678
# Education_num        -0.335779
# Marital_status       -0.357672
# Occupation            0.001951
# Relationship          0.703193
# Race                 -2.379913
# Sex                  -0.651314
# Capital_gain          0.000000
# Capital_loss          0.000000
# Hours_per_week        0.227554
# Native_country       -4.186524
# Income                1.578079

# %% [markdown]
# Skewness has been taken Cared of
#
# Capital_loss and gain has only zero in that column because it shows skewness due to Outliers and when i remove those Outlier so both the column has 0 now

# %%
plotnumber = 1
plt.figure(figsize=(15,30))
for i in new_df:
    if plotnumber < 16:
        ax = plt.subplot(8,2,plotnumber)
        sns.kdeplot(new_df[i],data=new_df,fill=True)
        plt.xlabel(i,fontsize=10)
        plotnumber+=1
plt.show()

# %%
sns.countplot(new_df["Income"],data=new_df)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %% [markdown]
# There is huge class imbalanced

# %%
## Using smote to balances the Target columns
from sklearn.utils import resample
zero = new_df[new_df["Income"]==0]# Less than 50k
one = new_df[new_df["Income"]==1]# Greater than 50k

# %%
up_sampled = resample(one,replace=True,n_samples=len(zero),random_state=0)

# %%
new_df=pd.concat([zero,up_sampled])

# %%
new_df["Income"].value_counts()
# Out:
# 1.0    22939
# 0.0    22939
# Name: Income, dtype: int64

# %%
sns.countplot(new_df["Income"],data=new_df)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %% [markdown]
# Class imbalancement has been taken cared

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split,cross_val_score,KFold
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.decomposition import PCA
from sklearn.svm import SVC

# %%
x = new_df.drop(columns=["Income"],axis=1)
y = new_df["Income"]

# %%
scale = StandardScaler()
x_scaled = scale.fit_transform(x)

# %%
# Fixing the random state in cross validation to stop fluctuation in cv score every time we run
kf = KFold(n_splits=5,random_state=114)

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.30,random_state=114)

# %%
diff= []
cross = []
accu = []

# %% [markdown]
# ### LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)

# %%
a = accuracy_score(y_test,y_pred)

# %%
c = cross_val_score(lr,x_scaled,y,cv=kf).mean()

# %%
accu.append(a)
cross.append(c)
diff.append(a-c)

# %%
print("Accuracy score is :",a,"\n","=-"*60,"\nCross_validation_score is :",c,"\n","=-"*60,"\n Classification Report :\n",
      classification_report(y_test,y_pred),"\n","=-"*60,"\nConfusion Matrix :\n",confusion_matrix(y_test,y_pred))
# Out:
# Accuracy score is : 0.7481110142400464
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Cross_validation_score is : 0.6295166587876441
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
#  Classification Report :
#                precision    recall  f1-score   support
#
#          0.0       0.76      0.73      0.74      6888
#          1.0       0.74      0.77      0.75      6876
#
#     accuracy                           0.75     13764
#    macro avg       0.75      0.75      0.75     13764
# weighted avg       0.75      0.75      0.75     13764
#
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Confusion Matrix :
#  [[4998 1890]
#  [1577 5299]]

# %% [markdown]
# ### BaggingClassifier

# %%
bag_clf = BaggingClassifier()
bag_clf.fit(x_train,y_train)
# Out:
# BaggingClassifier()

# %%
y_pred = bag_clf.predict(x_test)

# %%
a = accuracy_score(y_test,y_pred)

# %%
c = cross_val_score(bag_clf,x_scaled,y,cv=kf).mean()

# %%
accu.append(a)
cross.append(c)
diff.append(a-c)

# %%
print("Accuracy score is :",a,"\n","=-"*60,"\nCross_validation_score is :",c,"\n","=-"*60,"\n Classification Report :\n",
      classification_report(y_test,y_pred),"\n","=-"*60,"\nConfusion Matrix :\n",confusion_matrix(y_test,y_pred))
# Out:
# Accuracy score is : 0.9255303690787562
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Cross_validation_score is : 0.9073648636770726
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
#  Classification Report :
#                precision    recall  f1-score   support
#
#          0.0       0.97      0.88      0.92      6888
#          1.0       0.89      0.97      0.93      6876
#
#     accuracy                           0.93     13764
#    macro avg       0.93      0.93      0.93     13764
# weighted avg       0.93      0.93      0.93     13764
#
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Confusion Matrix :
#  [[6043  845]
#  [ 180 6696]]

# %% [markdown]
# ### RandomForestClassifier

# %%
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(x_test)

# %%
a = accuracy_score(y_test,y_pred)

# %%
c = cross_val_score(rf,x_scaled,y,cv=kf).mean()

# %%
accu.append(a)
cross.append(c)
diff.append(a-c)

# %%
print("Accuracy score is :",a,"\n","=-"*60,"\nCross_validation_score is :",c,"\n","=-"*60,"\n Classification Report :\n",
      classification_report(y_test,y_pred),"\n","=-"*60,"\nConfusion Matrix :\n",confusion_matrix(y_test,y_pred))
# Out:
# Accuracy score is : 0.9290177274048241
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Cross_validation_score is : 0.9123567272995066
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
#  Classification Report :
#                precision    recall  f1-score   support
#
#          0.0       0.98      0.88      0.93      6888
#          1.0       0.89      0.98      0.93      6876
#
#     accuracy                           0.93     13764
#    macro avg       0.93      0.93      0.93     13764
# weighted avg       0.93      0.93      0.93     13764
#
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Confusion Matrix :
#  [[6032  856]
#  [ 121 6755]]

# %% [markdown]
# ### GradientClassifier

# %%
gbc = GradientBoostingClassifier()
gbc.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred = gbc.predict(x_test)

# %%
a = accuracy_score(y_test,y_pred)

# %%
c = cross_val_score(gbc,x_scaled,y,cv=kf).mean()

# %%
accu.append(a)
cross.append(c)
diff.append(a-c)

# %%
print("Accuracy score is :",a,"\n","=-"*60,"\nCross_validation_score is :",c,"\n","=-"*60,"\n Classification Report :\n",
      classification_report(y_test,y_pred),"\n","=-"*60,"\nConfusion Matrix :\n",confusion_matrix(y_test,y_pred))
# Out:
# Accuracy score is : 0.8239610578320256
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Cross_validation_score is : 0.7542838752437945
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
#  Classification Report :
#                precision    recall  f1-score   support
#
#          0.0       0.86      0.78      0.82      6888
#          1.0       0.80      0.87      0.83      6876
#
#     accuracy                           0.82     13764
#    macro avg       0.83      0.82      0.82     13764
# weighted avg       0.83      0.82      0.82     13764
#
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Confusion Matrix :
#  [[5373 1515]
#  [ 908 5968]]

# %% [markdown]
# ### KNeighborsClassifier

# %%
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(x_test)

# %%
a = accuracy_score(y_test,y_pred)

# %%
c = cross_val_score(knn,x_scaled,y,cv=kf).mean()

# %%
accu.append(a)
cross.append(c)
diff.append(a-c)

# %%
print("Accuracy score is :",a,"\n","=-"*60,"\nCross_validation_score is :",c,"\n","=-"*60,"\n Classification Report :\n",
      classification_report(y_test,y_pred),"\n","=-"*60,"\nConfusion Matrix :\n",confusion_matrix(y_test,y_pred))
# Out:
# Accuracy score is : 0.8415431560592851
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Cross_validation_score is : 0.7969645705299218
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
#  Classification Report :
#                precision    recall  f1-score   support
#
#          0.0       0.91      0.75      0.83      6888
#          1.0       0.79      0.93      0.85      6876
#
#     accuracy                           0.84     13764
#    macro avg       0.85      0.84      0.84     13764
# weighted avg       0.85      0.84      0.84     13764
#
#  =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-
# Confusion Matrix :
#  [[5197 1691]
#  [ 490 6386]]

# %%
models = ["LogisticRegression","BaggingClassifier","RandomForest","GradientClassifier",
          "KNeighborsClassifier"]

# %%
classification = pd.DataFrame({"Models":models,
                              "Accuracies":accu,
                              "Cross_validation_score":cross,
                              "Difference":diff})

classification
# Out:
#                  Models  Accuracies  Cross_validation_score  Difference
# 0    LogisticRegression    0.748111                0.629517    0.118594
# 1     BaggingClassifier    0.925530                0.907365    0.018166
# 2          RandomForest    0.929018                0.912357    0.016661
# 3    GradientClassifier    0.823961                0.754284    0.069677
# 4  KNeighborsClassifier    0.841543                0.796965    0.044579

# %% [markdown]
# ## RandomForestClassifier is my best model

# %%
from sklearn.model_selection import RandomizedSearchCV
param = {"n_estimators":[100,900,1000],
        "criterion":["gini","entropy"],
        "min_samples_split":[2,3,5,4,],
        "max_features":["auto","sqrt","log2"],
        "bootstrap":[True,False],
        "max_depth":[35,37,40]}

# %%
rand = RandomizedSearchCV(r_,param_distributions=param,cv=3)
rand.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=3,
#                    estimator=RandomForestClassifier(bootstrap=False,
#                                                     criterion='entropy',
#                                                     max_depth=37,
#                                                     n_estimators=900),
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['gini', 'entropy'],
#                                         'max_depth': [35, 37, 40],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_split': [2, 3, 5, 4],
#                                         'n_estimators': [100, 900, 1000]})

# %%
rand.best_params_
# Out:
# {'n_estimators': 100,
#  'min_samples_split': 3,
#  'max_features': 'sqrt',
#  'max_depth': 37,
#  'criterion': 'gini',
#  'bootstrap': False}

# %%
rf =RandomForestClassifier(n_estimators=100,min_samples_split=3,max_features='sqrt',max_depth=37,criterion='gini',bootstrap=False)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=37, max_features='sqrt',
#                        min_samples_split=3)

# %%
ypred1 = rf.predict(x_test)

# %%
accuracy_score(y_test,ypred1)
# Out:
# 0.9414414414414415

# %%
cross_val_score(rf,x_scaled,y,cv=kf).mean()
# Out:
# 0.9270687850547216

# %%
print("Classification Report \n", classification_report(y_test,ypred1))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#          0.0       0.98      0.91      0.94      6888
#          1.0       0.91      0.98      0.94      6876
#
#     accuracy                           0.94     13764
#    macro avg       0.94      0.94      0.94     13764
# weighted avg       0.94      0.94      0.94     13764

# %%
confusion_matrix(y_test,ypred1)
# Out:
# array([[6237,  651],
#        [ 155, 6721]], dtype=int64)

# %%
classification
# Out:
#                  Models  Accuracies  Cross_validation_score  Difference
# 0    LogisticRegression    0.748111                0.629517    0.118594
# 1     BaggingClassifier    0.925530                0.907365    0.018166
# 2          RandomForest    0.929018                0.912357    0.016661
# 3    GradientClassifier    0.823961                0.754284    0.069677
# 4  KNeighborsClassifier    0.841543                0.796965    0.044579

# %%
from sklearn.metrics import roc_curve,roc_auc_score,plot_roc_curve

#LogisticRegression
print("LogisticRegression roc_auc_score :",roc_auc_score(y_test,lr.predict(x_test)))


#BaggingClassifier
print("BaggingClassifier roc_auc_score :",roc_auc_score(y_test,bag_clf.predict(x_test)))

#RandomForest
print("RandomForest roc_auc_score :",roc_auc_score(y_test,rf.predict(x_test)))

#GradientBoosting
print("GradientBoosting roc_auc_score :",roc_auc_score(y_test,gbc.predict(x_test)))

#KNeighbors
print("KNeighborsClassifier roc_auc_score :",roc_auc_score(y_test,knn.predict(x_test)))
# Out:
# LogisticRegression roc_auc_score : 0.7481306488457555
# BaggingClassifier roc_auc_score : 0.9255724349502283
# RandomForest roc_auc_score : 0.941472814597256
# GradientBoosting roc_auc_score : 0.823999372660144
# KNeighborsClassifier roc_auc_score : 0.8416191094409073

# %%
plt.style.use('seaborn')

disp = plot_roc_curve(rf,x_test,y_test,color='orange')
plot_roc_curve(knn,x_test,y_test,color='green',ax=disp.ax_)
plot_roc_curve(gbc,x_test,y_test,color='red',ax=disp.ax_)
plot_roc_curve(bag_clf,x_test,y_test,ax=disp.ax_)
plot_roc_curve(lr,x_test,y_test,ax=disp.ax_)

plt.title('ROC curve')

plt.xlabel('False Positive Rate')

plt.ylabel('True Positive rate')

plt.legend(loc='best')
plt.savefig('ROC',dpi=300)
plt.show();

# %% [markdown]
# ### Saving the best Model

# %%
import pickle
pickle.dump(rf,open("Census.pk1","wb"))

# %%
load_model = pickle.load(open("Census.pk1","rb"))
